# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Input
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv('student-mat.csv', sep=";")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
df.shape
# Out:
# (395, 33)

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
X= df.drop(columns=["G3"])
Y=df['G3']

# %%
cat_cols=X.select_dtypes(include='object').columns.tolist()
X = pd.get_dummies(X, columns=cat_cols, drop_first=True).astype(int)
# Out:
# C:\Users\visha\AppData\Local\Temp\ipykernel_19772\3111392661.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols=X.select_dtypes(include='object').columns.tolist()

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
df.shape
# Out:
# (395, 33)

# %%
model = Sequential([
    Input(shape=(x_train.shape[1],)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1)
])

model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

model.summary()

history = model.fit(
    x_train,
    y_train,
    epochs=50,
    batch_size=33,
    validation_split=0.2 
)

test_loss, test_accuracy = model.evaluate(x_test, y_test) 

print(f"\nTest Accuracy: {test_accuracy:.4f}")

predictions = model.predict(x_test[:10]) 


for i in range(10):
    print(
        f"Actual: {y_test.iloc[i]} | Predicted: {predictions[i][0]:.2f}"
    )
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         5,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,697 (53.50 KB)
#  Trainable params: 13,697 (53.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 124.6820 - mae: 10.1869 - val_loss: 109.8404 - val_mae: 9.7608
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 101.0714 - mae: 9.1860 - val_loss: 84.8719 - val_mae: 8.5809
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 72.9721 - mae: 7.7872 - val_loss: 51.8496 - val_mae: 6.6216
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 40.4291 - mae: 5.5685 - val_loss: 21.7362 - val_mae: 3.8255
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 24.4201 - mae: 3.9325 - val_loss: 16.1678 - val_mae: 2.8914
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 24.1292 - mae: 3.7508 - val_loss: 15.2599 - val_mae: 2.8318
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 21.3920 - mae: 3.5215 - val_loss: 15.1542 - val_mae: 2.9621
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 20.0410 - mae: 3.4787 - val_loss: 15.2484 - val_mae: 2.9990
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 19.3656 - mae: 3.4105 - val_loss: 14.2785 - val_mae: 2.8358
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 18.5604 - mae: 3.2798 - val_loss: 13.5961 - val_mae: 2.7098
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 17.8404 - mae: 3.1905 - val_loss: 13.3870 - val_mae: 2.6986
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 17.0722 - mae: 3.1101 - val_loss: 12.8649 - val_mae: 2.6256
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 16.2647 - mae: 3.0428 - val_loss: 12.5452 - val_mae: 2.6010
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 15.5118 - mae: 2.9480 - val_loss: 11.9535 - val_mae: 2.5000
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 14.6627 - mae: 2.8530 - val_loss: 11.7712 - val_mae: 2.5111
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 13.7278 - mae: 2.7407 - val_loss: 11.1009 - val_mae: 2.3821
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 12.8785 - mae: 2.6387 - val_loss: 10.7695 - val_mae: 2.3696
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 12.0407 - mae: 2.5662 - val_loss: 10.3591 - val_mae: 2.3154
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 11.2056 - mae: 2.4523 - val_loss: 9.9385 - val_mae: 2.2521
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 10.4644 - mae: 2.3577 - val_loss: 9.5296 - val_mae: 2.2050
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.6807 - mae: 2.2686 - val_loss: 9.1730 - val_mae: 2.1629
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.9158 - mae: 2.1742 - val_loss: 8.8021 - val_mae: 2.0995
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 8.2881 - mae: 2.1195 - val_loss: 8.5421 - val_mae: 2.0813
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 7.7242 - mae: 1.9693 - val_loss: 8.2860 - val_mae: 2.0050
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 7.1205 - mae: 1.9115 - val_loss: 8.0202 - val_mae: 2.0143
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 6.7450 - mae: 1.9184 - val_loss: 7.6846 - val_mae: 1.9457
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 6.3585 - mae: 1.7591 - val_loss: 7.4630 - val_mae: 1.9102
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 5.8845 - mae: 1.7489 - val_loss: 7.3425 - val_mae: 1.8959
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.5436 - mae: 1.6570 - val_loss: 7.1806 - val_mae: 1.8618
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 5.2319 - mae: 1.6309 - val_loss: 6.9542 - val_mae: 1.8627
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 4.9635 - mae: 1.5867 - val_loss: 6.7528 - val_mae: 1.8348
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 4.7114 - mae: 1.5347 - val_loss: 6.6685 - val_mae: 1.8172
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 4.4931 - mae: 1.4935 - val_loss: 6.5736 - val_mae: 1.7899
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.2807 - mae: 1.4734 - val_loss: 6.3734 - val_mae: 1.7514
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.1450 - mae: 1.4308 - val_loss: 6.2598 - val_mae: 1.7481
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 3.9583 - mae: 1.4449 - val_loss: 6.2085 - val_mae: 1.7284
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 3.7721 - mae: 1.3794 - val_loss: 6.1345 - val_mae: 1.6996
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.6159 - mae: 1.3741 - val_loss: 6.0210 - val_mae: 1.6798
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.4842 - mae: 1.3511 - val_loss: 5.9928 - val_mae: 1.6613
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 3.3408 - mae: 1.3276 - val_loss: 5.8897 - val_mae: 1.6790
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 3.1711 - mae: 1.2995 - val_loss: 5.8881 - val_mae: 1.6474
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.0686 - mae: 1.2755 - val_loss: 5.7959 - val_mae: 1.6839
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.9583 - mae: 1.2721 - val_loss: 5.7654 - val_mae: 1.6241
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.9417 - mae: 1.2573 - val_loss: 5.7454 - val_mae: 1.7533
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.9344 - mae: 1.2632 - val_loss: 5.6102 - val_mae: 1.6298
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.6898 - mae: 1.2257 - val_loss: 5.5892 - val_mae: 1.6160
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.5672 - mae: 1.1785 - val_loss: 5.4881 - val_mae: 1.6402
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.4226 - mae: 1.1616 - val_loss: 5.4609 - val_mae: 1.6177
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.3566 - mae: 1.1297 - val_loss: 5.4333 - val_mae: 1.6769
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.2975 - mae: 1.1228 - val_loss: 5.3809 - val_mae: 1.6230
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.3042 - mae: 1.8215
#
# Test Accuracy: 1.8215
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Actual: 10 | Predicted: 6.94
# Actual: 12 | Predicted: 13.90
# Actual: 5 | Predicted: 2.33
# Actual: 10 | Predicted: 9.82
# Actual: 9 | Predicted: 10.39
# Actual: 13 | Predicted: 10.73
# Actual: 18 | Predicted: 19.49
# Actual: 6 | Predicted: 8.85
# Actual: 0 | Predicted: 6.09
# Actual: 14 | Predicted: 11.60
